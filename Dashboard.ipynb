# %% [markdown]
# # Dashboard

# %% [markdown]
# ## Übersicht

# %% [markdown]
# #### Hallo, Stefanie!

# %%
my_dictionary = {"Matrikelnummer": "XX12345678", "Studiengang": "Medizinische Informatik"}
print(my_dictionary)
# Out:
# {'Matrikelnummer': 'XX12345678', 'Studiengang': 'Medizinische Informatik'}

# %%
def average(grades):
    return sum(grades) / len(grades)

grades = [2.0, 2.7]
average = average(grades)
print(f"Deine Durchschnittsnote ist: {average}")
# Out:
# Deine Durchschnittsnote ist: 2.35

# %%
import pandas as pd
import matplotlib.pyplot as plt


Module = ['E-Health', 'Medizin für Nichtmediziner:innen I']
series = pd.Series([5, 5], index= Module, name="Module")

my_colors= ['lightseagreen','blueviolet'] 

series.plot.pie(figsize=(5, 5), fontsize=12, colors=my_colors, autopct='%.2f %%')

plt.show()
